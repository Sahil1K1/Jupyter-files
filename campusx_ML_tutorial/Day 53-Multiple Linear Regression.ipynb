# %% [markdown]
# ##### Equation for multiple linear regression

# %% [markdown]
# ![image.png](attachment:1760ddb5-3dc2-4d76-a13f-adabcb3870ad.png)

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.linear_model

# %%
a = 5

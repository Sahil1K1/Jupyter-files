# %%
with open(r'values.txt', 'r') as fp:
    # read all lines using readline()
    lines = fp.readlines()

# %%
lines
# Out:
# ['****** Start Log Message ******\n',
#  'Web Recorder version : 2023.0.0.506 \n',
#  'Recording Mode: HTML-based script containing explicit URLs only\n',
#  'Recording headers in list:\n',
#  '\taccept-language\n',
#  '\tx-gwt-permutation\n',
#  'Not excluding content types\n',
#  'Do not record this content types as a resource:\n',
#  '\ttext/html\n',
#  '\ttext/xml\n',
#  '\tapplication/json\n',
#  'Reset context between actions\n',
#  'Do not record non-HTML elements\n',
#  'Protocol Type: Multi-QTWeb\n',
#  '\n',
#  '$$$$$$ End Log Message $$$$$$\n',
#  '\n',
#  'Code generation version: 2023.0.0.506\n',
#  '\n',
#  '****** Analyze segments filter initialization ******\n',
#  '****** Request Header For Transaction With Id 2 ******\n',
#  'GET http://petstore.smartload.io/applicationPetstore/shopping/main.xhtml HTTP/1.1\n',
#  'Upgrade-Insecure-Requests: 1\n',
# ...

# %%
for i in lines:
    i.count("-8061265872692079024:8742617355473775262")
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
type(lines)
# Out:
# list

# %%
a = [20, 400, 10, 20, 4, 100, 5, 2]

# %%
s = a[0]
for i in range(1,len(a)-1):
    if s > a[i]:
        s = s
    else:
        s = a[i]
    # print(s)
print(s)
# Out:
# 400

# %%
for i in range(1, len(a)):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.datasets import make_classification

# %%
X1, y1 = make_classification(n_samples=1500, n_features=2, n_informative=1, n_redundant=0, 
                          n_classes=2, n_clusters_per_class=1, random_state=41, hypercube=False, class_sep=8)

# %%
X1[:,0].shape
# Out:
# (1500,)

# %%
y1
# Out:
# array([1, 1, 0, ..., 0, 0, 1])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(X1[:,0], X1[:,1], c=y1, cmap='winter');
